# %%
# Install required packages
# !pip install -q langchain sentence-transformers faiss-cpu pypdf tiktoken requests

# Import libraries
import os
from typing import Optional, List, Mapping, Any
import requests
from pypdf import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.llms.base import LLM
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

## Step 1: Custom DeepSeek LLM Wrapper
class DeepSeekLLM(LLM):
    api_key: str
    model: str = "deepseek-chat"
    temperature: float = 0.7
    max_tokens: int = 1000

    @property
    def _llm_type(self) -> str:
        return "deepseek"

    def _call(self, prompt: str, stop: Optional[List[str]] = None) -> str:
        headers = {
            "Authorization": f"Bearer {self.api_key}",
            "Content-Type": "application/json"
        }
        payload = {
            "model": self.model,
            "messages": [{"role": "user", "content": prompt}],
            "temperature": self.temperature,
            "max_tokens": self.max_tokens
        }
        response = requests.post(
            "https://api.deepseek.com/v1/chat/completions",
            headers=headers,
            json=payload
        )
        return response.json()["choices"][0]["message"]["content"]

    @property
    def _identifying_params(self) -> Mapping[str, Any]:
        return {
            "model": self.model,
            "temperature": self.temperature,
            "max_tokens": self.max_tokens
        }

## Step 2: Load and Process PDF
def load_and_chunk_pdf(file_path):
    # Load PDF
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    
    # Split into chunks
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=100,
        length_function=len
    )
    return text_splitter.split_text(text)

## Step 3: Create Vector Store
def create_vector_store(chunks):
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
    return FAISS.from_texts(chunks, embeddings)

## Step 4: Initialize RAG Pipeline
def initialize_rag_pipeline(api_key, vector_store):
    # Create prompt template
    prompt_template = """Use the following context to answer the question.
    If you don't know the answer, say you don't know. Be precise and technical.

    Context:
    {context}

    Question: {question}
    Answer:"""

    PROMPT = PromptTemplate(
        template=prompt_template,
        input_variables=["context", "question"]
    )

    # Initialize LLM
    llm = DeepSeekLLM(api_key=api_key)

    # Create QA chain
    return RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vector_store.as_retriever(search_kwargs={"k": 3}),
        chain_type_kwargs={"prompt": PROMPT},
        return_source_documents=True
    )

## Step 5: Query Function
def ask_question(qa_chain, question):
    result = qa_chain({"query": question})
    print("🧠 Answer:", result["result"])
    print("\n📚 Sources:")
    for i, doc in enumerate(result["source_documents"]):
        print(f"\nSource {i+1}:")
        print(doc.page_content[:300] + "...")

## Main Execution
if __name__ == "__main__":
    # Get API key from Kaggle Secrets
    from kaggle_secrets import UserSecretsClient
    secrets = UserSecretsClient()
    DEEPSEEK_API_KEY = secrets.get_secret("DEEPSEEK_API_KEY")
    
    # Load and process PDF (replace with your file path)
    print("Loading and processing PDF...")
    chunks = load_and_chunk_pdf("/kaggle/input/human-and-ai-written/Human_and_AI_Written_Text_Detection_Using_Deep_Learning_and_Machine_Learning.pdf")
    
    # Create vector store
    print("Creating vector database...")
    vector_store = create_vector_store(chunks)
    
    # Initialize RAG pipeline
    print("⚙️ Initializing RAG pipeline...")
    qa_chain = initialize_rag_pipeline(DEEPSEEK_API_KEY, vector_store)
    
    # Example questions
    questions = [
        "What is the main contribution of this paper?",
        "What methodology did the authors use?",
        "What were the key findings?",
        "What datasets were used in this research?"
    ]
    
    # Ask questions
    print("\n💬 Ready for questions! Here are some examples:")
    for q in questions:
        print(f"\n❓ Question: {q}")
        ask_question(qa_chain, q)
    
    # Interactive mode
    print("\n🎤 Enter your own questions (type 'quit' to exit):")
    while True:
        user_question = input("\nYour question: ")
        if user_question.lower() == 'quit':
            break
        ask_question(qa_chain, user_question)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 📄 Loading and processing PDF...
# 🔍 Creating vector database...
# ⚙️ Initializing RAG pipeline...
#
# 💬 Ready for questions! Here are some examples:
#
# ❓ Question: What is the main contribution of this paper?
# 🧠 Answer: The main contribution of the paper appears to be the development and evaluation of machine learning models (specifically Bi-LSTM and Bi-GRU) for classifying human-generated versus AI-generated text. The paper details preprocessing techniques (tokenization, padding, vectorization) and model architectures to distinguish subtle differences between AI and human writing.
#
# However, the provided context is fragmented, and key sections (e.g., abstract, conclusions) are missing, so the exact novelty (e.g., dataset creation, model performance benchmarks) cannot be definitively stated. For a precise answer, the full paper would need to be reviewed.
#
# Based on the excerpts, the focus is on:
# 1. **Methodology**: Use of bidirectional RNN variants (Bi-LSTM/Bi-GRU) for improved context understanding in text classification.
# 2. **Preprocessing**: Detailed pipeline (embedding, vectorization) to prepare text data for model training.
# 3. **Application**: Addressing challenges in AI-generated text detection, possibly with implications for scientific manuscripts (as hinted by citation [5]).
#
# If you need a more specific contribution (e.g., performance metrics, dataset introduction), please provide additional context.
#
# 📚 Sources:
#
# Source 1:
# AI text when ChatGPT is told to write like a chemist,” Cell Reports
# Physical Science, vol. 4, no. 11, 2023.
# [4] M. S. Salim and S. I. Hossain, ”An Applied Statistics dataset for
# human vs AI-generated answer classification,” Data in Brief, vol. 54,
# pp. 110240, 2024.
# [5] H. H. Rashidi, B. D. Fennell, ...
#
# Source 2:
# text due to its complex architecture.
# Bi-GRU (Bidirectional Gated Recurrent Unit): It is another
# type of RNN variant. That improves context-understanding by
# processing information in both forward and backward direc-
# tions. It enhances context comprehension and distinguishes
# subtle differences betwee...
#
# Source 3:
# the sequences. Here, the chosen value of Embedding DIM is
# 100.
# Vectorizer: The padded sequences transform into numerical
# vectors by applying vectorizer and preparing text data suitable
# for input into machine learning models.
# Preprocessed Data: This large dataset has been processed
# after applying met...
#
# ❓ Question: What methodology did the authors use?
# 🧠 Answer: The authors employed a comparative methodology by evaluating multiple models (LSTM, Bi-GRU, Gradient Boosting, and Decision Tree) for their performance in distinguishing AI-generated text from human-written text. Key metrics analyzed include **False Negatives** (AI-written texts misclassified as human-written) and misclassification rates of human-written texts. The study emphasizes the importance of context-relevant training data, preprocessing, and detection accuracy, particularly for applications in academic and professional plagiarism detection. The models were tested on datasets containing both AI-generated (e.g., GPT) and human-written texts, with a focus on optimizing accuracy and efficiency.
#
# (Note: The context is fragmented, so the methodology is inferred from the available details.)
#
# 📚 Sources:
#
# Source 1:
# itives. LSTM (399) and Bi-GRU (467) show the number of
# human-written texts which are incorrectly predicted as AI-
# written.
# False Negative (AI Written): This metric shows the number
# of AI-generated texts which is incorrectly classified as human-
# written. The Gradient Boosting model shows the highest ...
#
# Source 2:
# percentage of human-generated scientific abstracts are mis-
# classified as AI-generated [5]. The study emphasizes the need
# for context-relevant training data and proper preprocessing to
# enhance detection accuracy and it is helpful in educational and
# professional coding contexts to detect plagiarism [...
#
# Source 3:
# GPT which are trained with large datasets widely used to
# produce content by Artificial Intelligence. In academic and
# professional domains, the difference between human-written
# and AI-generated is crucial with the help of trustworthy
# detection mechanisms [1]. Gathering a large amount of human-
# writte...
#
# ❓ Question: What were the key findings?
# 🧠 Answer: The key findings from the provided context are as follows:
#
# 1. **Need for Effective Detection Tools**: There is a highlighted need for tools to detect and label the quality and authenticity of academic literature, particularly to distinguish between human and AI-generated text.
#
# 2. **Dataset Importance**: A comprehensive dataset of question-and-answer pairs is essential for developing AI detection models that compare human and AI-generated responses.
#
# 3. **Challenges in AI Text Detection**: Recent research indicates significant inaccuracies in AI text detection tools, including misclassification of human-generated scientific abstracts as AI-generated.
#
# 4. **Performance of Detection Models**:
#    - **Bi-GRU Model**: Achieved the highest accuracy (**99.69%**), outperforming other reported methods.
#    - Other notable models and their accuracies:
#      - **XGBoost (2023)**: 99.00%
#      - **DistilBERT (2024)**: 92.00%
#      - **GPTSniffer (2024)**: 99.00%
#      - **Ensemble LLM (2023)**: 75.10%
#      - **LLM-Detector (2024)**: 98.52%
#      - **GBDT Ensemble (2024)**: 99.20%
#
# 5. **Human vs. AI Detection**: Studies (e.g., Liu et al., 2024) compare human and AI detectors in identifying LLM-generated medical writing, emphasizing ongoing challenges in detection reliability.
#
# 6. **Vulnerability Detection**: Research (e.g., Li & Shan) explores LLM-based vulnerability detection, though specific findings are not detailed in the excerpt.
#
# In summary, the key takeaway is that while AI detection tools (especially Bi-GRU) achieve high accuracy, challenges remain in distinguishing human and AI-generated text reliably.
#
# 📚 Sources:
#
# Source 1:
# highlighting the need for an effective detection tool and label
# the quality and authenticity of academic literature [3]. A
# comprehensive dataset of question-and-answer pairs help to
# produce an AI detection model for comparing human and
# AI-generated responses [4]. This academic work examines
# the chal...
#
# Source 2:
# Conference on Machine Learning and Applications (ICMLA), 2023, pp.
# 864–870.
# [11] J. Q. Liu, K. T. Hui, F. Al Zoubi, Z. Z. Zhou, D. Samartzis, C. C. Yu,
# J. R. Chang, and A. Y . Wong, ”The great detectives: humans versus AI
# detectors in catching large language model-generated medical writing,”
# Interna...
#
# Source 3:
# XGBoost [3] 2023 Machine Learning 99.00%
# DistilBERT [4] 2024 Deep Learning 92.00%
# GPTSniffer [6] 2024 Deep Learning 99.00%
# Ensemble LLM [9] 2023 Deep Learning 75.10%
# LLM-Detector [14] 2024 Deep Learning 98.52%
# GBDT Ensemble [15] 2024 Machine Learning 99.20%
# Our Model, Bi-GRU Deep Learning 99.69%
# In ...
#
# ❓ Question: What datasets were used in this research?
# 🧠 Answer: The provided context does not specify the exact datasets used in the research. It mentions that the dataset was split into 80% training and 20% testing data, and that preprocessing methods like tokenization, padding, and vectorization were applied. However, the name or source of the dataset(s) is not disclosed in the given text.
#
# If you need further details, you may refer to the cited reference "[1]" in the context or the full paper (IEEE publication, DOI: 979-8-3315-1909-4/24/$31.00 ©2024 IEEE) for explicit dataset information.
#
# Answer: The context does not specify the datasets used.
#
# 📚 Sources:
#
# Source 1:
# training. Data Splitting: The dataset has been splittted into
# 80% for train data and 20% for test data.
# Model Training: Here, we introduce 4 different models.
# Decision Tree and Gradient Boosting are from the machine
# learning section as well as LSTM (Long Short-Term Memory)
# and Bi-GRU (Bidirectional ...
#
# Source 2:
# the sequences. Here, the chosen value of Embedding DIM is
# 100.
# Vectorizer: The padded sequences transform into numerical
# vectors by applying vectorizer and preparing text data suitable
# for input into machine learning models.
# Preprocessed Data: This large dataset has been processed
# after applying met...
#
# Source 3:
# GPT which are trained with large datasets widely used to
# produce content by Artificial Intelligence. In academic and
# professional domains, the difference between human-written
# and AI-generated is crucial with the help of trustworthy
# detection mechanisms [1]. Gathering a large amount of human-
# writte...
#
# 🎤 Enter your own questions (type 'quit' to exit):
# Your question:  exit
# 🧠 Answer: It seems like your question is incomplete or unclear. If you're asking about the performance of AI text detection models (e.g., Bi-GRU, LSTM, XGBoost, etc.) based on the provided context, I can summarize:
#
# - The **Bi-GRU model** achieves the highest accuracy (99.69%) in distinguishing AI-generated vs. human-written text, outperforming other methods like XGBoost (99%), DistilBERT (92%), and ensemble models.
# - **LSTM and Bi-GRU** misclassify fewer AI-generated texts as human-written (617 and 541 errors, respectively) compared to other models.
# - The table and bar chart highlight the superior performance of deep learning models (especially Bi-GRU) over machine learning and other deep learning approaches.
#
# If you meant something else by "exit," please clarify your question. Otherwise, let me know if you'd like more details on specific models or metrics.
#
# 📚 Sources:
#
# Source 1:
# AI text when ChatGPT is told to write like a chemist,” Cell Reports
# Physical Science, vol. 4, no. 11, 2023.
# [4] M. S. Salim and S. I. Hossain, ”An Applied Statistics dataset for
# human vs AI-generated answer classification,” Data in Brief, vol. 54,
# pp. 110240, 2024.
# [5] H. H. Rashidi, B. D. Fennell, ...
#
# Source 2:
# XGBoost [3] 2023 Machine Learning 99.00%
# DistilBERT [4] 2024 Deep Learning 92.00%
# GPTSniffer [6] 2024 Deep Learning 99.00%
# Ensemble LLM [9] 2023 Deep Learning 75.10%
# LLM-Detector [14] 2024 Deep Learning 98.52%
# GBDT Ensemble [15] 2024 Machine Learning 99.20%
# Our Model, Bi-GRU Deep Learning 99.69%
# In ...
#
# Source 3:
# written texts. The LSTM and Bi-GRU models have superior
# performance which presents 617 and 541 AI-written texts
# incorrectly classified as human-written respectively.
# This bar chart presents the significant differences in error
# 542
# Authorized licensed use limited to: University of Science & Technolog...
# Your question:  exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_141/945220145.py in <cell line: 0>()
#     149         if user_question.lower() == 'quit':
#     150             break
# --> 151         ask_question(qa_chain, user_question)
#
# /tmp/ipykernel_141/945220145.py in ask_question(qa_chain, question)
#     103 ## Step 5: Query Function
#     104 def ask_question(qa_chain, question):
# --> 105     result = qa_chain({"query": question})
#     106     print("🧠 Answer:", result["result"])
#     107     print("\n📚 Sources:")
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     384         }
#     385
# --> 386         return self.invoke(
#     387             inputs,
#     388             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     165         except BaseException as e:
#     166             run_manager.on_chain_error(e)
# --> 167             raise e
#     168         run_manager.on_chain_end(outputs)
#     169
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     155             self._validate_inputs(inputs)
#     156             outputs = (
# --> 157                 self._call(inputs, run_manager=run_manager)
#     158                 if new_arg_supported
#     159                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     152         else:
#     153             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 154         answer = self.combine_documents_chain.run(
#     155             input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     156         )
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     606
#     607         if kwargs and not args:
# --> 608             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     609                 _output_key
#     610             ]
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     384         }
#     385
# --> 386         return self.invoke(
#     387             inputs,
#     388             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     165         except BaseException as e:
#     166             run_manager.on_chain_error(e)
# --> 167             raise e
#     168         run_manager.on_chain_end(outputs)
#     169
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     155             self._validate_inputs(inputs)
#     156             outputs = (
# --> 157                 self._call(inputs, run_manager=run_manager)
#     158                 if new_arg_supported
#     159                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     136         # Other keys are assumed to be needed for LLM prediction
#     137         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 138         output, extra_return_dict = self.combine_docs(
#     139             docs, callbacks=_run_manager.get_child(), **other_keys
#     140         )
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     257         inputs = self._get_inputs(docs, **kwargs)
#     258         # Call predict on the LLM.
# --> 259         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     260
#     261     async def acombine_docs(
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     317                 completion = llm.predict(adjective="funny")
#     318         """
# --> 319         return self(kwargs, callbacks=callbacks)[self.output_key]
#     320
#     321     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     384         }
#     385
# --> 386         return self.invoke(
#     387             inputs,
#     388             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     165         except BaseException as e:
#     166             run_manager.on_chain_error(e)
# --> 167             raise e
#     168         run_manager.on_chain_end(outputs)
#     169
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     155             self._validate_inputs(inputs)
#     156             outputs = (
# --> 157                 self._call(inputs, run_manager=run_manager)
#     158                 if new_arg_supported
#     159                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     125         run_manager: Optional[CallbackManagerForChainRun] = None,
#     126     ) -> dict[str, str]:
# --> 127         response = self.generate([inputs], run_manager=run_manager)
#     128         return self.create_outputs(response)[0]
#     129
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     137         callbacks = run_manager.get_child() if run_manager else None
#     138         if isinstance(self.llm, BaseLanguageModel):
# --> 139             return self.llm.generate_prompt(
#     140                 prompts,
#     141                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     764     ) -> LLMResult:
#     765         prompt_strings = [p.to_string() for p in prompts]
# --> 766         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     767
#     768     @override
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     971                 )
#     972             ]
# --> 973             return self._generate_helper(
#     974                 prompts,
#     975                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     790         try:
#     791             output = (
# --> 792                 self._generate(
#     793                     prompts,
#     794                     stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1547                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1548                 if new_arg_supported
# -> 1549                 else self._call(prompt, stop=stop, **kwargs)
#    1550             )
#    1551             generations.append([Generation(text=text)])
#
# /tmp/ipykernel_141/945220145.py in _call(self, prompt, stop)
#      36             "max_tokens": self.max_tokens
#      37         }
# ---> 38         response = requests.post(
#      39             "https://api.deepseek.com/v1/chat/completions",
#      40             headers=headers,
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1061         """
#    1062         if self.chunked and self.supports_chunked_reads():
# -> 1063             yield from self.read_chunked(amt, decode_content=decode_content)
#    1064         else:
#    1065             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#    1217
#    1218             while True:
# -> 1219                 self._update_chunk_length()
#    1220                 if self.chunk_left == 0:
#    1221                     break
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _update_chunk_length(self)
#    1136         if self.chunk_left is not None:
#    1137             return None
# -> 1138         line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139         line = line.split(b";", 1)[0]
#    1140         try:
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
